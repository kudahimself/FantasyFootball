# %%
import pandas as pd

df_check = pd.DataFrame(

[['2025-2026','2025-08-17','Premier League','1','1', '0-1',None,90,0,0,None,0.0],
['2025-2026','2025-08-24','Premier League','2','10','1-1',None,90,0,0,None,0.0],
['2025-2026','2025-08-24','Premier League','2','10','1-1',None,90,0,0,None,0.0]], columns=['Season', 'Date','Comp', 'Round', 'Opponent', 'Result', 'Pos', 'Min', 'Gls', 'Ast', 'Points', 'Elo'])

# %%
df_check.drop_duplicates(subset = ['Season', 'Date'], keep='last', inplace=True)

# %%
df_check
# Out:
#       Season        Date            Comp Round Opponent Result   Pos  Min  \
# 0  2025-2026  2025-08-17  Premier League     1        1    0-1  None   90
# 2  2025-2026  2025-08-24  Premier League     2       10    1-1  None   90
#
#    Gls  Ast Points  Elo
# 0    0    0   None  0.0
# 2    0    0   None  0.0

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import aiohttp
from bs4 import BeautifulSoup
import pandas as pd

# %%
import aiohttp
from fpl import FPL

async def get_all_fpl_player_names():
    async with aiohttp.ClientSession() as session:
        fpl = FPL(session)
        players = await fpl.get_players()
        names = [f"{player.first_name} {player.second_name}" for player in players]
        return names

# In a notebook cell, use:
names = await get_all_fpl_player_names()
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\envs\venv\Lib\urllib\request.py:1348, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1347 try:
# -> 1348     h.request(req.get_method(), req.selector, req.data, headers,
#    1349               encode_chunked=req.has_header('Transfer-encoding'))
#    1350 except OSError as err: # timeout error
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\http\client.py:1303, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1302 """Send a complete request to the server."""
# -> 1303 self._send_request(method, url, body, headers, encode_chunked)
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\http\client.py:1349, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1348     body = _encode(body, 'body')
# -> 1349 self.endheaders(body, encode_chunked=encode_chunked)
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\http\client.py:1298, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1297     raise CannotSendHeader()
# -> 1298 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\http\client.py:1058, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1057 del self._buffer[:]
# -> 1058 self.send(msg)
#    1060 if message_body is not None:
#    1061
#    1062     # create a consistent interface to message_body
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\http\client.py:996, in HTTPConnection.send(self, data)
#     995 if self.auto_open:
# --> 996     self.connect()
#     997 else:
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\http\client.py:1475, in HTTPSConnection.connect(self)
#    1473     server_hostname = self.host
# -> 1475 self.sock = self._context.wrap_socket(self.sock,
#    1476                                       server_hostname=server_hostname)
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\ssl.py:517, in SSLContext.wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     511 def wrap_socket(self, sock, server_side=False,
#     512                 do_handshake_on_connect=True,
#     513                 suppress_ragged_eofs=True,
#     514                 server_hostname=None, session=None):
#     515     # SSLSocket class handles server_hostname encoding before it calls
#     516     # ctx._wrap_socket()
# --> 517     return self.sslsocket_class._create(
#     518         sock=sock,
#     519         server_side=server_side,
#     520         do_handshake_on_connect=do_handshake_on_connect,
#     521         suppress_ragged_eofs=suppress_ragged_eofs,
#     522         server_hostname=server_hostname,
#     523         context=self,
#     524         session=session
#     525     )
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\ssl.py:1104, in SSLSocket._create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1103                 raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1104             self.do_handshake()
#    1105 except:
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\ssl.py:1382, in SSLSocket.do_handshake(self, block)
#    1381         self.settimeout(None)
# -> 1382     self._sslobj.do_handshake()
#    1383 finally:
#
# SSLCertVerificationError: [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# Cell In[2], line 12
#       9         return names
#      11 # In a notebook cell, use:
# ---> 12 names = await get_all_fpl_player_names()
#
# Cell In[2], line 6, in get_all_fpl_player_names()
#       4 async def get_all_fpl_player_names():
#       5     async with aiohttp.ClientSession() as session:
# ----> 6         fpl = FPL(session)
#       7         players = await fpl.get_players()
#       8         names = [f"{player.first_name} {player.second_name}" for player in players]
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\site-packages\fpl\fpl.py:51, in FPL.__init__(self, session)
#      48 def __init__(self, session):
#      49     self.session = session
# ---> 51     resp = urlopen(API_URLS["static"], context=ssl_context)
#      52     static = json.loads(resp.read().decode("utf-8"))
#      53     for k, v in static.items():
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\urllib\request.py:519, in OpenerDirector.open(self, fullurl, data, timeout)
#     516     req = meth(req)
#     518 sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 519 response = self._open(req, data)
#     521 # post-process response
#     522 meth_name = protocol+"_response"
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\urllib\request.py:536, in OpenerDirector._open(self, req, data)
#     533     return result
#     535 protocol = req.type
# --> 536 result = self._call_chain(self.handle_open, protocol, protocol +
#     537                           '_open', req)
#     538 if result:
#     539     return result
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\urllib\request.py:1391, in HTTPSHandler.https_open(self, req)
#    1390 def https_open(self, req):
# -> 1391     return self.do_open(http.client.HTTPSConnection, req,
#    1392         context=self._context, check_hostname=self._check_hostname)
#
# File c:\ProgramData\anaconda3\envs\venv\Lib\urllib\request.py:1351, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1348         h.request(req.get_method(), req.selector, req.data, headers,
#    1349                   encode_chunked=req.has_header('Transfer-encoding'))
#    1350     except OSError as err: # timeout error
# -> 1351         raise URLError(err)
#    1352     r = h.getresponse()
#    1353 except:
#
# URLError: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1016)>

# %%
import os
import pandas as pd

def get_fbref_ids_selenium(names, save_path="fbref_ids2.csv"):
    """
    Given a list of player names, use Selenium to search FBref and extract the player ID from the redirected URL.
    Skips names already processed and saves progress to a CSV file.
    """
    # Load existing results if file exists
    if os.path.exists(save_path):
        df_existing = pd.read_csv(save_path)
        done_names = set(df_existing['name'])
        results = df_existing.values.tolist()
    else:
        done_names = set()
        results = []

    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
    for name in names:
        try:
            if name in done_names:
                continue
            search_url = f"https://fbref.com/en/search/search.fcgi?search={requests.utils.quote(name)}"
            driver.get(search_url)
            final_url = driver.current_url
            parts = final_url.split("/")
            found_id = None
            if "players" in parts:
                idx = parts.index("players")
                if idx + 1 < len(parts):
                    found_id = parts[idx + 1]
            results.append([name, found_id])
            # Save after each lookup
            pd.DataFrame(results, columns=["name", "id"]).to_csv(save_path, index=False, encoding='utf-8')
        except Exception as e:
            print(f"Error processing {name}: {e}")
            results.append([name, None])
    driver.quit()
    return results

# Example usage
ids = get_fbref_ids_selenium(names)

# %%
id = '79300479'
url = f'https://fbref.com/en/players/{id}/matchlogs/2024-2025/Martin-Odegaard-Match-Logs'

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
driver.get(url)

soup = BeautifulSoup(driver.page_source, 'html.parser')
driver.quit()

# Extract subheaders (second row of headers) and use them as DataFrame columns
table = soup.find('table', id='matchlogs_all')
if table:
    rows = table.find_all('tr')
    # Use the second row of headers (subheaders)
    subheaders = [header.text for header in rows[1].find_all('th')]
    # Insert 'Date' as the first column
    print('Subheaders:', subheaders)
    # Extract the first column (Date) along with the rest of the cells
    cells = [rows[3].find('th').text] + [cell.text for cell in rows[3].find_all('td')]
    print(cells)
    data = []
    for row in rows[2:]:
        print('herer')
        cells = [row.find('th').text] + [cell.text for cell in row.find_all('td')]
        if len(cells) == len(subheaders):
            data.append(cells)
        else:
            print(f'Skipped row with {len(cells)} columns (expected {len(subheaders)})')
    df = pd.DataFrame(data, columns=subheaders)
    display(df.head())
else:
    print('Match logs table not found.')

# %%
import os

years = ['2022-2023', '2023-2024', '2024-2025']
df_ids = pd.read_csv("fbref_ids2.csv",encoding='utf-8')

output_folder = "fbref_data"
os.makedirs(output_folder, exist_ok=True)

for _, row in df_ids.iterrows():
    try:
        player_id = row['id']
        player_name = row['name']
        filename = os.path.join(output_folder, f"{player_name.replace(' ', '_')}.csv")
        if os.path.exists(filename):
            print(f"CSV already exists for {player_name}, skipping.")
            continue
        player_data = []
        if pd.notnull(player_id):
            for year in years:
                driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
                url = f'https://fbref.com/en/players/{player_id}/matchlogs/{year}/{player_name.replace(" ", "-")}-Match-Logs'
                driver.get(url)
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                driver.quit()
                table = soup.find('table', id='matchlogs_all')
                if table:
                    rows = table.find_all('tr')
                    subheaders = [header.text for header in rows[1].find_all('th')]
                    for row in rows[2:]:
                        cells = [row.find('th').text] + [cell.text for cell in row.find_all('td')]
                        if len(cells) == len(subheaders):
                            player_data.append([year] + cells)
                else:
                    print(f'Match logs table not found for {player_name} ({year})')
            # Save to CSV if data exists
            if player_data:
                columns = ['Season'] + subheaders
                df_player = pd.DataFrame(player_data, columns=columns)
                df_player.to_csv(filename, index=False)
    except Exception as e:
        print(f"Error processing {player_name}: {e}")
# Out:
# CSV already exists for David Raya Martín, skipping.
# CSV already exists for Kepa Arrizabalaga Revuelta, skipping.
# CSV already exists for Tommy Setford, skipping.
# CSV already exists for Gabriel Magalhães, skipping.
# CSV already exists for William Saliba, skipping.
# CSV already exists for Riccardo Calafiori, skipping.
# CSV already exists for Jurriën Timber, skipping.
# CSV already exists for Jakub Kiwior, skipping.
# CSV already exists for Myles Lewis-Skelly, skipping.
# CSV already exists for Benjamin White, skipping.
# CSV already exists for Oleksandr Zinchenko, skipping.
# CSV already exists for Brayden Clarke, skipping.
# CSV already exists for Maldini Kacurri, skipping.
# CSV already exists for Josh Nichols, skipping.
# CSV already exists for Bukayo Saka, skipping.
# CSV already exists for Martin Ødegaard, skipping.
# CSV already exists for Noni Madueke, skipping.
# CSV already exists for Gabriel Martinelli Silva, skipping.
# CSV already exists for Leandro Trossard, skipping.
# CSV already exists for Declan Rice, skipping.
# CSV already exists for Mikel Merino Zazón, skipping.
# CSV already exists for Fábio Ferreira Vieira, skipping.
# CSV already exists for Christian Nørgaard, skipping.
# CSV already exists for Ethan Nwaneri, skipping.
# CSV already exists for Martín Zubimendi Ibáñez, skipping.
# CSV already exists for Reiss Nelson, skipping.
# CSV already exists for Ismeal Kabia, skipping.
# CSV already exists for Albert Sambi Lokonga, skipping.
# CSV already exists for Kai Havertz, skipping.
# CSV already exists for Gabriel Fernando de Jesus, skipping.
# CSV already exists for Cristhian Mosquera, skipping.
# CSV already exists for Viktor Gyökeres, skipping.
# CSV already exists for Emiliano Martínez, skipping.
# CSV already exists for Marco Bizot, skipping.
# CSV already exists for Joe Gauci, skipping.
# Error processing Filip Marschall: 22 columns passed, passed data had 38 columns
# CSV already exists for Matty Cash, skipping.
# CSV already exists for Lucas Digne, skipping.
# CSV already exists for Ezri Konsa Ngoyo, skipping.
# CSV already exists for Ian Maatsen, skipping.
# CSV already exists for Tyrone Mings, skipping.
# Match logs table not found for Pau Torres (2022-2023)
# Match logs table not found for Pau Torres (2023-2024)
# Match logs table not found for Pau Torres (2024-2025)
# CSV already exists for Álex Moreno Lopera, skipping.
# CSV already exists for Lamare Bogarde, skipping.
# CSV already exists for Yasin Özcan, skipping.
# CSV already exists for Morgan Rogers, skipping.
# CSV already exists for Youri Tielemans, skipping.
# CSV already exists for Leon Bailey, skipping.
# CSV already exists for Emiliano Buendía Stati, skipping.
# CSV already exists for Samuel Iling-Junior, skipping.
# CSV already exists for Jacob Ramsey, skipping.
# CSV already exists for Donyell Malen, skipping.
# CSV already exists for John McGinn, skipping.
# CSV already exists for Ross Barkley, skipping.
# CSV already exists for Enzo Barrenechea, skipping.
# CSV already exists for Lewis Dobbin, skipping.
# CSV already exists for Boubacar Kamara, skipping.
# CSV already exists for Amadou Onana, skipping.
# CSV already exists for Ben Broggio, skipping.
# CSV already exists for Leander Dendoncker, skipping.
# CSV already exists for Jamaldeen Jimoh, skipping.
# CSV already exists for Kadan Young, skipping.
# CSV already exists for Ollie Watkins, skipping.
# CSV already exists for Zépiqueno Redmond, skipping.
# CSV already exists for Evann Guessand, skipping.
# CSV already exists for Max Weiß, skipping.
# CSV already exists for Etienne Green, skipping.
# CSV already exists for Václav Hladký, skipping.
# CSV already exists for Connor Roberts, skipping.
# CSV already exists for Hannes Delcroix, skipping.
# CSV already exists for Owen Dodgson, skipping.
# CSV already exists for Hjalmar Ekdal, skipping.
# CSV already exists for Maxime Estève, skipping.
# CSV already exists for Quilindschy Hartman, skipping.
# CSV already exists for Bashir Humphreys, skipping.
# CSV already exists for Jordan Beyer, skipping.
# CSV already exists for Lucas Pires Silva, skipping.
# CSV already exists for Shurandy Sambo, skipping.
# CSV already exists for Oliver Sonne, skipping.
# CSV already exists for Axel Tuanzebe, skipping.
# CSV already exists for Joe Worrall, skipping.
# CSV already exists for Jaidon Anthony, skipping.
# CSV already exists for Jacob Bruun Larsen, skipping.
# CSV already exists for Enock Agyei, skipping.
# CSV already exists for Darko Churlinov, skipping.
# CSV already exists for Josh Cullen, skipping.
# CSV already exists for Marcus Edwards, skipping.
# CSV already exists for Hannibal Mejbri, skipping.
# CSV already exists for Luca Koleosho, skipping.
# CSV already exists for Josh Laurent, skipping.
# CSV already exists for Loum Tchaouna, skipping.
# CSV already exists for Oluwaseun Adewumi, skipping.
# CSV already exists for Jaydon Banel, skipping.
# Error processing Mike Trésor Ndayishimiye: 30 columns passed, passed data had 38 columns
# CSV already exists for Zian Flemming, skipping.
# CSV already exists for Zeki Amdouni, skipping.
# CSV already exists for Lyle Foster, skipping.
# CSV already exists for Ashley Barnes, skipping.
# CSV already exists for Michael Obafemi, skipping.
# CSV already exists for Martin Dúbravka, skipping.
# CSV already exists for Lesley Ugochukwu, skipping.
# CSV already exists for Armando Broja, skipping.
# CSV already exists for Norberto Murara Neto, skipping.
# CSV already exists for Đorđe Petrović, skipping.
# CSV already exists for Callan McKenna, skipping.
# CSV already exists for Alex Paulsen, skipping.
# CSV already exists for Illia Zabarnyi, skipping.
# CSV already exists for Marcos Senesi Barón, skipping.
# CSV already exists for Adam Smith, skipping.
# CSV already exists for Adrien Truffert, skipping.
# CSV already exists for Matai Akinmboni, skipping.
# Match logs table not found for Owen Bevan (2024-2025)
# Error processing Owen Bevan: 30 columns passed, passed data had 38 columns
# CSV already exists for James Hill, skipping.
# CSV already exists for Chris Mepham, skipping.
# CSV already exists for Julio Soler Barreto, skipping.
# CSV already exists for Justin Kluivert, skipping.
# CSV already exists for Antoine Semenyo, skipping.
# CSV already exists for Dango Ouattara, skipping.
# CSV already exists for Marcus Tavernier, skipping.
# CSV already exists for Tyler Adams, skipping.
# CSV already exists for David Brooks, skipping.
# CSV already exists for Ryan Christie, skipping.
# CSV already exists for Lewis Cook, skipping.
# CSV already exists for Philip Billing, skipping.
# CSV already exists for Alex Scott, skipping.
# CSV already exists for Luis Sinisterra, skipping.
# CSV already exists for Romain Faivre, skipping.
# CSV already exists for Hamed Traorè, skipping.
# Error processing Dominic Sadi: 30 columns passed, passed data had 38 columns
# CSV already exists for Zain Silcott-Duberry, skipping.
# CSV already exists for Ben Winterburn, skipping.
# CSV already exists for Francisco Evanilson de Lima Barbosa, skipping.
# CSV already exists for Enes Ünal, skipping.
# CSV already exists for Daniel Adu-Adjei, skipping.
# Match logs table not found for Eli Junior Kroupi (2024-2025)
# CSV already exists for Bafodé Diakité, skipping.
# CSV already exists for Caoimhín Kelleher, skipping.
# CSV already exists for Ellery Balcombe, skipping.
# CSV already exists for Matthew Cox, skipping.
# CSV already exists for Julian Eyestone, skipping.
# CSV already exists for Nathan Collins, skipping.
# CSV already exists for Keane Lewis-Potter, skipping.
# CSV already exists for Kristoffer Ajer, skipping.
# CSV already exists for Rico Henry, skipping.
# CSV already exists for Michael Kayode, skipping.
# CSV already exists for Ethan Pinnock, skipping.
# CSV already exists for Sepp van den Berg, skipping.
# CSV already exists for Benjamin Arthur, skipping.
# CSV already exists for Benjamin Fredrick, skipping.
# Error processing Aaron Hickey: 30 columns passed, passed data had 38 columns
# CSV already exists for Jayden Meghoma, skipping.
# CSV already exists for Kevin Schade, skipping.
# CSV already exists for Mikkel Damsgaard, skipping.
# CSV already exists for Antoni Milambo, skipping.
# CSV already exists for Jordan Henderson, skipping.
# CSV already exists for Vitaly Janelt, skipping.
# CSV already exists for Mathias Jensen, skipping.
# CSV already exists for Gustavo Nunes Fernandes Gomes, skipping.
# CSV already exists for Frank Onyeka, skipping.
# CSV already exists for Yehor Yarmoliuk, skipping.
# Error processing Romelle Donovan: 30 columns passed, passed data had 38 columns
# CSV already exists for Yunus Emre Konak, skipping.
# CSV already exists for Paris Maghoma, skipping.
# CSV already exists for Myles Peart-Harris, skipping.
# CSV already exists for Ryan Trevitt, skipping.
# CSV already exists for Yoane Wissa, skipping.
# CSV already exists for Igor Thiago Nascimento Rodrigues, skipping.
# CSV already exists for Iwan Morgan, skipping.
# CSV already exists for Jason Steele, skipping.
# CSV already exists for Bart Verbruggen, skipping.
# CSV already exists for Tom McGill, skipping.
# CSV already exists for Carl Rushworth, skipping.
# CSV already exists for Kjell Scherpen, skipping.
# CSV already exists for Olivier Boscagli, skipping.
# CSV already exists for Diego Coppola, skipping.
# CSV already exists for Maxim De Cuyper, skipping.
# CSV already exists for Lewis Dunk, skipping.
# CSV already exists for Pervis Estupiñán Tenorio, skipping.
# CSV already exists for Ferdi Kadıoğlu, skipping.
# CSV already exists for Igor Julio dos Santos de Paulo, skipping.
# CSV already exists for Tariq Lamptey, skipping.
# CSV already exists for Jan Paul van Hecke, skipping.
# CSV already exists for Joël Veltman, skipping.
# CSV already exists for Adam Webster, skipping.
# CSV already exists for Eiran Cashin, skipping.
# Error processing Jacob Slater: 30 columns passed, passed data had 38 columns
# CSV already exists for Charlie Tasker, skipping.
# CSV already exists for Mitoma Kaoru, skipping.
# CSV already exists for Georginio Rutter, skipping.
# CSV already exists for Solly March, skipping.
# CSV already exists for Yankuba Minteh, skipping.
# CSV already exists for Julio Enciso Espínola, skipping.
# CSV already exists for Brajan Gruda, skipping.
# CSV already exists for Jack Hinshelwood, skipping.
# CSV already exists for Matt O'Riley, skipping.
# CSV already exists for Abdallah Sima, skipping.
# CSV already exists for Yasin Ayari, skipping.
# CSV already exists for Carlos Baleba, skipping.
# CSV already exists for Facundo Buonanotte, skipping.
# CSV already exists for Diego Gómez Amarilla, skipping.
# CSV already exists for James Milner, skipping.
# CSV already exists for Jeremy Sarmiento Morante, skipping.
# CSV already exists for Mats Wieffer, skipping.
# CSV already exists for Malick Yalcouyé, skipping.
# CSV already exists for Joe Knight, skipping.
# CSV already exists for Adrian Mazilu, skipping.
# CSV already exists for Andrew Moran, skipping.
# CSV already exists for Danny Welbeck, skipping.
# CSV already exists for Evan Ferguson, skipping.
# Error processing Stefanos Tzimas: 30 columns passed, passed data had 38 columns
# CSV already exists for Charalampos Kostoulas, skipping.
# CSV already exists for Robert Lynch Sánchez, skipping.
# CSV already exists for Filip Jörgensen, skipping.
# CSV already exists for Mike Penders, skipping.
# CSV already exists for Marc Cucurella, skipping.
# CSV already exists for Reece James, skipping.
# CSV already exists for Trevoh Chalobah, skipping.
# CSV already exists for Levi Colwill, skipping.
# CSV already exists for Malo Gusto, skipping.
# CSV already exists for Benoît Badiashile Mukinayi, skipping.
# CSV already exists for Wesley Fofana, skipping.
# CSV already exists for Mamadou Sarr, skipping.
# CSV already exists for Tosin Adarabioyo, skipping.
# CSV already exists for Josh Acheampong, skipping.
# CSV already exists for Aarón Anselmino, skipping.
# CSV already exists for Cole Palmer, skipping.
# Match logs table not found for Pedro Neto (2022-2023)
# Match logs table not found for Pedro Neto (2023-2024)
# Match logs table not found for Pedro Neto (2024-2025)
# CSV already exists for Enzo Fernández, skipping.
# CSV already exists for Estêvão Almeida de Oliveira Gonçalves, skipping.
# CSV already exists for Jamie Bynoe-Gittens, skipping.
# CSV already exists for Christopher Nkunku, skipping.
# CSV already exists for Moisés Caicedo Corozo, skipping.
# CSV already exists for Tyrique George, skipping.
# CSV already exists for Roméo Lavia, skipping.
# CSV already exists for Mykhailo Mudryk, skipping.
# CSV already exists for Andrey Nascimento dos Santos, skipping.
# CSV already exists for Dário Luís Essugo, skipping.
# CSV already exists for Kendry Páez Andrade, skipping.
# CSV already exists for João Pedro Junqueira de Jesus, skipping.
# CSV already exists for Liam Delap, skipping.
# CSV already exists for Nicolas Jackson, skipping.
# CSV already exists for Jorrel Hato, skipping.
# CSV already exists for Dean Henderson, skipping.
# CSV already exists for Walter Benítez, skipping.
# Error processing Remi Matthews: 22 columns passed, passed data had 38 columns
# CSV already exists for Daniel Muñoz Mejía, skipping.
# CSV already exists for Maxence Lacroix, skipping.
# CSV already exists for Tyrick Mitchell, skipping.
# CSV already exists for Borna Sosa, skipping.
# CSV already exists for Marc Guéhi, skipping.
# CSV already exists for Chris Richards, skipping.
# CSV already exists for Nathaniel Clyne, skipping.
# CSV already exists for Rob Holding, skipping.
# CSV already exists for Caleb Kporha, skipping.
# CSV already exists for Eberechi Eze, skipping.
# CSV already exists for Ismaïla Sarr, skipping.
# CSV already exists for Cheick Doucouré, skipping.
# CSV already exists for Romain Esse, skipping.
# CSV already exists for Daichi Kamada, skipping.
# CSV already exists for Jefferson Lerma Solís, skipping.
# CSV already exists for Adam Wharton, skipping.
# CSV already exists for Asher Agbinone, skipping.
# CSV already exists for Naouirou Ahamada, skipping.
# CSV already exists for Justin Devenny, skipping.
# CSV already exists for Malcolm Ebiowei, skipping.
# CSV already exists for Jesurun Rak-Sakyi, skipping.
# CSV already exists for Matheus França de Oliveira, skipping.
# CSV already exists for David Ozoh, skipping.
# CSV already exists for Kaden Rodney, skipping.
# CSV already exists for Franco Umeh-Chibueze, skipping.
# CSV already exists for Jean-Philippe Mateta, skipping.
# CSV already exists for Eddie Nketiah, skipping.
# CSV already exists for Odsonne Édouard, skipping.
# CSV already exists for Zach Marsh, skipping.
# CSV already exists for Kiernan Dewsbury-Hall, skipping.
# CSV already exists for Jordan Pickford, skipping.
# CSV already exists for Mark Travers, skipping.
# CSV already exists for Harry Tyrer, skipping.
# CSV already exists for Jarrad Branthwaite, skipping.
# CSV already exists for James Tarkowski, skipping.
# CSV already exists for Vitalii Mykolenko, skipping.
# CSV already exists for Jake O'Brien, skipping.
# CSV already exists for Séamus Coleman, skipping.
# CSV already exists for Nathan Patterson, skipping.
# CSV already exists for Roman Dixon, skipping.
# CSV already exists for Reece Welch, skipping.
# CSV already exists for Iliman Ndiaye, skipping.
# CSV already exists for Dwight McNeil, skipping.
# CSV already exists for Idrissa Gana Gueye, skipping.
# CSV already exists for James Garner, skipping.
# CSV already exists for Tim Iroegbunam, skipping.
# CSV already exists for Harrison Armstrong, skipping.
# CSV already exists for Callum Bates, skipping.
# CSV already exists for Coby Ebere, skipping.
# CSV already exists for Isaac Heath, skipping.
# CSV already exists for Jenson Metcalfe, skipping.
# CSV already exists for Norberto Bercique Gomes Betuncal, skipping.
# CSV already exists for Youssef Ramalho Chermiti, skipping.
# CSV already exists for Martin Sherif, skipping.
# CSV already exists for Jack Grealish, skipping.
# CSV already exists for Adam Aznou, skipping.
# CSV already exists for Bernd Leno, skipping.
# Error processing Steven Benda: 22 columns passed, passed data had 38 columns
# CSV already exists for Antonee Robinson, skipping.
# CSV already exists for Joachim Andersen, skipping.
# CSV already exists for Calvin Bassey, skipping.
# CSV already exists for Timothy Castagne, skipping.
# CSV already exists for Issa Diop, skipping.
# CSV already exists for Jorge Cuenca Barreno, skipping.
# CSV already exists for Kenny Tete, skipping.
# CSV already exists for Samuel Amissah, skipping.
# CSV already exists for Alex Iwobi, skipping.
# CSV already exists for Emile Smith Rowe, skipping.
# CSV already exists for Adama Traoré Diarra, skipping.
# CSV already exists for Andreas Hoelgebaum Pereira, skipping.
# CSV already exists for Ryan Sessegnon, skipping.
# CSV already exists for Harry Wilson, skipping.
# CSV already exists for Sander Berge, skipping.
# CSV already exists for Tom Cairney, skipping.
# CSV already exists for Saša Lukić, skipping.
# CSV already exists for Martial Godo, skipping.
# Error processing Luke Harris: 30 columns passed, passed data had 38 columns
# CSV already exists for Harrison Reed, skipping.
# CSV already exists for Raúl Jiménez Rodríguez, skipping.
# CSV already exists for Rodrigo Muniz Carvalho, skipping.
# CSV already exists for Benjamin Lecomte, skipping.
# CSV already exists for Illan Meslier, skipping.
# CSV already exists for Alex Cairns, skipping.
# CSV already exists for Karl Darlow, skipping.
# CSV already exists for Jayden Bogle, skipping.
# CSV already exists for Pascal Struijk, skipping.
# CSV already exists for Jaka Bijol, skipping.
# CSV already exists for Sebastiaan Bornauw, skipping.
# CSV already exists for Sam Byram, skipping.
# CSV already exists for Gabriel Gudmundsson, skipping.
# CSV already exists for Joe Rodon, skipping.
# CSV already exists for Isaac Schmidt, skipping.
# CSV already exists for Brenden Aaronson, skipping.
# CSV already exists for Wilfried Gnonto, skipping.
# CSV already exists for Jack Harrison, skipping.
# CSV already exists for Ethan Ampadu, skipping.
# CSV already exists for Sam Greenwood, skipping.
# CSV already exists for Ilia Gruev, skipping.
# CSV already exists for Largie Ramazani, skipping.
# CSV already exists for Tanaka Ao, skipping.
# CSV already exists for Charlie Crew, skipping.
# CSV already exists for Joe Gelhardt, skipping.
# CSV already exists for Darko Gyabi, skipping.
# CSV already exists for Joël Piroe, skipping.
# CSV already exists for Patrick Bamford, skipping.
# CSV already exists for Mateo Joseph Fernández-Regatillo, skipping.
# CSV already exists for Lukas Nmecha, skipping.
# CSV already exists for Sean Longstaff, skipping.
# CSV already exists for Anton Stach, skipping.
# CSV already exists for Alisson Becker, skipping.
# CSV already exists for Giorgi Mamardashvili, skipping.
# CSV already exists for Ármin Pécsi, skipping.
# CSV already exists for Freddie Woodman, skipping.
# CSV already exists for Jeremie Frimpong, skipping.
# CSV already exists for Milos Kerkez, skipping.
# CSV already exists for Andrew Robertson, skipping.
# CSV already exists for Virgil van Dijk, skipping.
# CSV already exists for Ibrahima Konaté, skipping.
# CSV already exists for Conor Bradley, skipping.
# CSV already exists for Joe Gomez, skipping.
# CSV already exists for Konstantinos Tsimikas, skipping.
# CSV already exists for Amara Nallo, skipping.
# Error processing Rhys Williams: 30 columns passed, passed data had 38 columns
# Error processing Calvin Ramsay: 30 columns passed, passed data had 38 columns
# CSV already exists for Florian Wirtz, skipping.
# CSV already exists for Luis Díaz Marulanda, skipping.
# CSV already exists for Cody Gakpo, skipping.
# CSV already exists for Federico Chiesa, skipping.
# CSV already exists for Alexis Mac Allister, skipping.
# CSV already exists for Dominik Szoboszlai, skipping.
# CSV already exists for Curtis Jones, skipping.
# CSV already exists for Harvey Elliott, skipping.
# CSV already exists for Ryan Gravenberch, skipping.
# CSV already exists for Ben Doak, skipping.
# CSV already exists for Endo Wataru, skipping.
# CSV already exists for James McConnell, skipping.
# CSV already exists for Tyler Morton, skipping.
# CSV already exists for Trey Nyoni, skipping.
# CSV already exists for Jayden Danns, skipping.
# CSV already exists for Hugo Ekitiké, skipping.
# CSV already exists for James Trafford, skipping.
# CSV already exists for Stefan Ortega Moreno, skipping.
# CSV already exists for Marcus Bettinelli, skipping.
# CSV already exists for Rayan Aït-Nouri, skipping.
# CSV already exists for Joško Gvardiol, skipping.
# CSV already exists for Manuel Akanji, skipping.
# CSV already exists for Nathan Aké, skipping.
# CSV already exists for Abdukodir Khusanov, skipping.
# CSV already exists for Matheus Nunes, skipping.
# CSV already exists for Rúben dos Santos Gato Alves Dias, skipping.
# CSV already exists for John Stones, skipping.
# CSV already exists for Rico Lewis, skipping.
# CSV already exists for Nico O'Reilly, skipping.
# CSV already exists for Vitor de Oliveira Nunes dos Reis, skipping.
# CSV already exists for Omar Marmoush, skipping.
# CSV already exists for Phil Foden, skipping.
# CSV already exists for Sávio Moreira de Oliveira, skipping.
# CSV already exists for Bernardo Mota Veiga de Carvalho e Silva, skipping.
# CSV already exists for Rayan Cherki, skipping.
# CSV already exists for Jérémy Doku, skipping.
# CSV already exists for İlkay Gündoğan, skipping.
# CSV already exists for Rodrigo 'Rodri' Hernandez Cascante, skipping.
# CSV already exists for Mateo Kovačić, skipping.
# CSV already exists for Nico González Iglesias, skipping.
# CSV already exists for Oscar Bobb, skipping.
# CSV already exists for Claudio Echeverri, skipping.
# CSV already exists for James McAtee, skipping.
# CSV already exists for Tijjani Reijnders, skipping.
# CSV already exists for Sverre Nypan, skipping.
# CSV already exists for Kalvin Phillips, skipping.
# CSV already exists for Erling Haaland, skipping.
# CSV already exists for Bryan Mbeumo, skipping.
# CSV already exists for Altay Bayındır, skipping.
# CSV already exists for André Onana, skipping.
# CSV already exists for Elyh Harrison, skipping.
# CSV already exists for Tom Heaton, skipping.
# CSV already exists for Dermot Mee, skipping.
# CSV already exists for Matthijs de Ligt, skipping.
# CSV already exists for Lisandro Martínez, skipping.
# CSV already exists for Noussair Mazraoui, skipping.
# CSV already exists for Diego León Blanco, skipping.
# CSV already exists for Diogo Dalot, skipping.
# CSV already exists for Patrick Dorgu, skipping.
# CSV already exists for Harry Maguire, skipping.
# CSV already exists for Luke Shaw, skipping.
# CSV already exists for Leny Yoro, skipping.
# CSV already exists for Harry Amass, skipping.
# CSV already exists for Tyler Fredricson, skipping.
# CSV already exists for Ayden Heaven, skipping.
# CSV already exists for Tyrell Malacia, skipping.
# CSV already exists for Bruno Fernandes, skipping.
# CSV already exists for Matheus Cunha, skipping.
# CSV already exists for Marcus Rashford, skipping.
# CSV already exists for Amad Diallo, skipping.
# CSV already exists for Alejandro Garnacho, skipping.
# CSV already exists for Antony dos Santos, skipping.
# CSV already exists for Mason Mount, skipping.
# CSV already exists for Jadon Sancho, skipping.
# CSV already exists for Carlos Henrique Casimiro, skipping.
# CSV already exists for Kobbie Mainoo, skipping.
# CSV already exists for Manuel Ugarte Ribeiro, skipping.
# CSV already exists for Toby Collyer, skipping.
# CSV already exists for Jack Fletcher, skipping.
# CSV already exists for Sékou Koné, skipping.
# CSV already exists for Jack Moorhouse, skipping.
# CSV already exists for Rasmus Højlund, skipping.
# CSV already exists for Joshua Zirkzee, skipping.
# CSV already exists for Chido Obi, skipping.
# Match logs table not found for Ethan Wheatley (2022-2023)
# Error processing Ethan Wheatley: 30 columns passed, passed data had 38 columns
# CSV already exists for Benjamin Sesko, skipping.
# CSV already exists for Nick Pope, skipping.
# Error processing Odysseas Vlachodimos: 22 columns passed, passed data had 38 columns
# CSV already exists for Lewis Hall, skipping.
# CSV already exists for Fabian Schär, skipping.
# CSV already exists for Sven Botman, skipping.
# CSV already exists for Dan Burn, skipping.
# CSV already exists for Tino Livramento, skipping.
# CSV already exists for Kieran Trippier, skipping.
# CSV already exists for Emil Krafth, skipping.
# Error processing Jamaal Lascelles: 30 columns passed, passed data had 38 columns
# Error processing Alex Murphy: 30 columns passed, passed data had 38 columns
# CSV already exists for Harrison Ashby, skipping.
# CSV already exists for Miodrag Pivaš, skipping.
# CSV already exists for Matt Targett, skipping.
# CSV already exists for Anthony Gordon, skipping.
# CSV already exists for Anthony Elanga, skipping.
# CSV already exists for Harvey Barnes, skipping.
# CSV already exists for Bruno Guimarães Rodriguez Moura, skipping.
# CSV already exists for Jacob Murphy, skipping.
# CSV already exists for Joelinton, skipping.
# CSV already exists for Sandro Tonali, skipping.
# CSV already exists for Joe Willock, skipping.
# CSV already exists for Isaac Hayden, skipping.
# Error processing Garang Kuol: 30 columns passed, passed data had 38 columns
# CSV already exists for Lewis Miley, skipping.
# CSV already exists for Alexander Isak, skipping.
# CSV already exists for William Osula, skipping.
# CSV already exists for Sean Neave, skipping.
# CSV already exists for Aaron Ramsdale, skipping.
# CSV already exists for Malick Thiaw, skipping.
# CSV already exists for Matz Sels, skipping.
# CSV already exists for Carlos Miguel dos Santos Pereira, skipping.
# CSV already exists for Nikola Milenković, skipping.
# CSV already exists for Murillo Costa dos Santos, skipping.
# CSV already exists for Ola Aina, skipping.
# CSV already exists for Neco Williams, skipping.
# CSV already exists for Jair Paula da Cunha Filho, skipping.
# CSV already exists for Felipe Rodrigues da Silva, skipping.
# CSV already exists for Omar Richards, skipping.
# CSV already exists for Zach Abbott, skipping.
# CSV already exists for Willy Boly, skipping.
# CSV already exists for Morgan Gibbs-White, skipping.
# CSV already exists for Callum Hudson-Odoi, skipping.
# CSV already exists for Elliot Anderson, skipping.
# CSV already exists for João Pedro Ferreira da Silva, skipping.
# CSV already exists for Lewis O'Brien, skipping.
# CSV already exists for Ryan Yates, skipping.
# CSV already exists for Eric da Silva Moreira, skipping.
# CSV already exists for Marko Stamenić, skipping.
# CSV already exists for Chris Wood, skipping.
# CSV already exists for Igor Jesus Maciel da Cruz, skipping.
# CSV already exists for Taiwo Awoniyi, skipping.
# CSV already exists for Dan Ndoye, skipping.
# CSV already exists for Angus Gunn, skipping.
# CSV already exists for Marc Guiu Paz, skipping.
# CSV already exists for Anthony Patterson, skipping.
# CSV already exists for Daniel Ballard, skipping.
# CSV already exists for Trai Hume, skipping.
# CSV already exists for Aji Alese, skipping.
# CSV already exists for Dennis Cirkin, skipping.
# CSV already exists for Leo Fuhr Hjelde, skipping.
# CSV already exists for Niall Huggins, skipping.
# CSV already exists for Luke O'Nien, skipping.
# CSV already exists for Timothée Pembélé, skipping.
# CSV already exists for Reinildo Mandava, skipping.
# CSV already exists for Jenson Seelt, skipping.
# CSV already exists for Simon Adingra, skipping.
# CSV already exists for Habib Diarra, skipping.
# CSV already exists for Milan Aleksić, skipping.
# CSV already exists for Enzo Le Fée, skipping.
# CSV already exists for Romaine Mundle, skipping.
# CSV already exists for Noah Sadiki, skipping.
# CSV already exists for Chemsdine Talbi, skipping.
# CSV already exists for Alan Browne, skipping.
# CSV already exists for Pierre Ekwah Elimby, skipping.
# CSV already exists for Harrison Jones, skipping.
# Error processing Jay Matete: 30 columns passed, passed data had 38 columns
# CSV already exists for Nectarios Triantis, skipping.
# CSV already exists for Wilson Isidor, skipping.
# CSV already exists for Eliezer Mayenda Dossou, skipping.
# CSV already exists for Ahmed Abdullahi, skipping.
# Match logs table not found for Luís Hemir Silva Semedo (2022-2023)
# Error processing Luís Hemir Silva Semedo: 30 columns passed, passed data had 38 columns
# CSV already exists for Granit Xhaka, skipping.
# CSV already exists for Robin Roefs, skipping.
# CSV already exists for Arthur Masuaku, skipping.
# CSV already exists for Omar Alderete, skipping.
# CSV already exists for Guglielmo Vicario, skipping.
# CSV already exists for Brandon Austin, skipping.
# CSV already exists for Pedro Porro Sauceda, skipping.
# CSV already exists for Cristian Romero, skipping.
# CSV already exists for Kevin Danso, skipping.
# CSV already exists for Ben Davies, skipping.
# CSV already exists for Radu Drăgușin, skipping.
# CSV already exists for Djed Spence, skipping.
# CSV already exists for Destiny Udogie, skipping.
# CSV already exists for Micky van de Ven, skipping.
# CSV already exists for Takai Kōta, skipping.
# CSV already exists for Luka Vušković, skipping.
# CSV already exists for Son Heung-min, skipping.
# CSV already exists for Brennan Johnson, skipping.
# CSV already exists for James Maddison, skipping.
# CSV already exists for Mohammed Kudus, skipping.
# CSV already exists for Dejan Kulusevski, skipping.
# CSV already exists for Mathys Tel, skipping.
# CSV already exists for Rodrigo Bentancur, skipping.
# CSV already exists for Lucas Bergvall, skipping.
# CSV already exists for Yves Bissouma, skipping.
# CSV already exists for Wilson Odobert, skipping.
# CSV already exists for Manor Solomon, skipping.
# CSV already exists for Bryan Gil Salvatierra, skipping.
# CSV already exists for Archie Gray, skipping.
# CSV already exists for Mikey Moore, skipping.
# CSV already exists for Pape Matar Sarr, skipping.
# CSV already exists for Callum Olusesi, skipping.
# CSV already exists for Dominic Solanke-Mitchell, skipping.
# CSV already exists for Richarlison, skipping.
# CSV already exists for Will Lankshear, skipping.
# CSV already exists for Dane Scarlett, skipping.
# CSV already exists for Alphonse Areola, skipping.
# Error processing Wes Foderingham: 22 columns passed, passed data had 38 columns
# CSV already exists for Krisztián Hegyi, skipping.
# CSV already exists for El Hadji Malick Diouf, skipping.
# CSV already exists for Emerson Palmieri dos Santos, skipping.
# CSV already exists for Maximilian Kilman, skipping.
# CSV already exists for Konstantinos Mavropanos, skipping.
# CSV already exists for Nayef Aguerd, skipping.
# CSV already exists for Jean-Clair Todibo, skipping.
# CSV already exists for Aaron Wan-Bissaka, skipping.
# CSV already exists for Kaelan Casey, skipping.
# CSV already exists for Tomáš Souček, skipping.
# CSV already exists for James Ward-Prowse, skipping.
# CSV already exists for Crysencio Summerville, skipping.
# CSV already exists for Edson Álvarez Velázquez, skipping.
# CSV already exists for Maxwel Cornet, skipping.
# CSV already exists for Guido Rodríguez, skipping.
# CSV already exists for Luis Guilherme Lira dos Santos, skipping.
# CSV already exists for George Earthy, skipping.
# CSV already exists for Andy Irving, skipping.
# CSV already exists for Lewis Orford, skipping.
# CSV already exists for Freddie Potts, skipping.
# CSV already exists for Jarrod Bowen, skipping.
# CSV already exists for Niclas Füllkrug, skipping.
# Error processing Callum Marshall: 30 columns passed, passed data had 38 columns
# CSV already exists for Kyle Walker-Peters, skipping.
# CSV already exists for Mads Hermansen, skipping.
# CSV already exists for Sam Johnstone, skipping.
# CSV already exists for José Malheiro de Sá, skipping.
# CSV already exists for Daniel Bentley, skipping.
# CSV already exists for Emmanuel Agbadou, skipping.
# CSV already exists for Matt Doherty, skipping.
# CSV already exists for Yerson Mosquera Valdelamar, skipping.
# CSV already exists for Rodrigo Martins Gomes, skipping.
# CSV already exists for Toti Gomes, skipping.
# CSV already exists for Ki-Jana Hoever, skipping.
# Match logs table not found for Bastien Meupiyou Menadjou (2022-2023)
# Error processing Bastien Meupiyou Menadjou: 30 columns passed, passed data had 38 columns
# CSV already exists for Pedro Cardoso de Lima, skipping.
# CSV already exists for Alfie Pond, skipping.
# CSV already exists for Hwang Hee-chan, skipping.
# CSV already exists for André Trindade da Costa Neto, skipping.
# CSV already exists for Jean-Ricner Bellegarde, skipping.
# CSV already exists for Fer López González, skipping.
# CSV already exists for João Victor Gomes da Silva, skipping.
# CSV already exists for Gonçalo Manuel Ganchinho Guedes, skipping.
# CSV already exists for Marshall Munetsi, skipping.
# CSV already exists for Boubacar Traoré, skipping.
# CSV already exists for Tawanda Chirewa, skipping.
# CSV already exists for Tom Edozie, skipping.
# CSV already exists for Enso González Medina, skipping.
# CSV already exists for Jørgen Strand Larsen, skipping.
# CSV already exists for Fábio Soares Silva, skipping.
# CSV already exists for Saša Kalajdžić, skipping.
# Error processing Leon Chiwome: 30 columns passed, passed data had 38 columns
# Error processing Nathan Fraser: 30 columns passed, passed data had 38 columns
# CSV already exists for David Møller Wolfe, skipping.

# %%
import os

years = ['2022-2023', '2023-2024', '2024-2025']
df_ids = ['e342ad68']

output_folder = "fbref_data"
os.makedirs(output_folder, exist_ok=True)

for _, row in df_ids.iterrows():
    try:
        player_id = row['id']
        player_name = row['name']
        filename = os.path.join(output_folder, f"{player_name.replace(' ', '_')}.csv")
        if os.path.exists(filename):
            print(f"CSV already exists for {player_name}, skipping.")
            continue
        player_data = []
        if pd.notnull(player_id):
            for year in years:
                url = f'https://fbref.com/en/players/{player_id}/matchlogs/{year}/{player_name.replace(" ", "-")}-Match-Logs'
                driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()))
                driver.get(url)
                soup = BeautifulSoup(driver.page_source, 'html.parser')
                driver.quit()
                table = soup.find('table', id='matchlogs_all')
                if table:
                    rows = table.find_all('tr')
                    subheaders = [header.text for header in rows[1].find_all('th')]
                    for row in rows[2:]:
                        cells = [row.find('th').text] + [cell.text for cell in row.find_all('td')]
                        if len(cells) == len(subheaders):
                            player_data.append([year] + cells)
                else:
                    print(f'Match logs table not found for {player_name} ({year})')
            # Save to CSV if data exists
            if player_data:
                columns = ['Season'] + subheaders
                df_player = pd.DataFrame(player_data, columns=columns)
                df_player.to_csv(filename, index=False)
    except Exception as e:
        print(f"Error processing {player_name}: {e}")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[231], line 9
#       6 output_folder = "fbref_data"
#       7 os.makedirs(output_folder, exist_ok=True)
# ----> 9 for _, row in df_ids.iterrows():
#      10     try:
#      11         player_id = row['id']
#
# AttributeError: 'list' object has no attribute 'iterrows'

# %%
import re

df_player = pd.read_csv("./fbref_data/Erling_Haaland.csv")
df_player = df_player[df_player['Date'].notna() & (df_player['Date'].str.strip() != "")]
df_player = df_player[['Season', 'Date', 'Comp', 'Round', 'Opponent', 'Result', 'Pos', 'Min', 'Gls', 'Ast']]
df_player['Result'] = df_player['Result'].apply(lambda x: re.sub(r"\(\d+\)", "", x))
df_player['GoalsConceded'] = df_player['Result'].apply(
    lambda x: x.replace("W ", "")
               .replace("L ", "")
               .replace("D ", "")
               .replace("–", "-")
               .strip().split("-")[1]
)
df_player['GoalsScored'] = df_player['Result'].apply(
    lambda x: x.replace("W ", "")
               .replace("L ", "")
               .replace("D ", "")
               .replace("–", "-")
               .strip().split("-")[0]
)
df_player['CleanSheet'] = df_player['GoalsConceded'].astype(int).apply(lambda x: 1 if x == 0 else 0)
df_player['GoalDifference'] = df_player['GoalsScored'].astype(int) - df_player['GoalsConceded'].astype(int)
df_player.head()
# Out:
#       Season        Date                 Comp                Round  \
# 0  2022-2023  2022-06-02  UEFA Nations League             League B
# 1  2022-2023  2022-06-05  UEFA Nations League             League B
# 2  2022-2023  2022-06-09  UEFA Nations League             League B
# 3  2022-2023  2022-06-12  UEFA Nations League             League B
# 4  2022-2023  2022-07-30     Community Shield  FA Community Shield
#
#       Opponent Result Pos Min  Gls  Ast GoalsConceded GoalsScored  CleanSheet  \
# 0    rs Serbia  W 1–0  FW  66    1    0             0           1           1
# 1    se Sweden  W 2–1  FW  74    2    0             1           2           0
# 2  si Slovenia  D 0–0  FW  90    0    0             0           0           1
# 3    se Sweden  W 3–2  FW  88    2    1             2           3           0
# 4    Liverpool  L 1–3  FW  90    0    0             3           1           0
#
#    GoalDifference
# 0               1
# 1               1
# 2               0
# 3               1
# 4              -2

# %%
def get_player_position(df_player):
    positions = df_player['Pos'].dropna().astype(str)
    attacker_count = positions.str.count(r'(S|F|W)').sum()
    midfielder_count = positions.str.count(r'M').sum()
    defender_count = positions.str.count(r'B').sum()
    keeper_count = positions.str.count(r'G').sum()
    counts = {
        'Attacker': attacker_count,
        'Midfielder': midfielder_count,
        'Defender': defender_count,
        'Keeper': keeper_count
    }
    main_position = max(counts, key=counts.get)
    return main_position

get_player_position(df_player)
# Out:
# 'Attacker'

# %%
def midfielder_points(df_player):
    """
    Calculate points for a midfielder based on goals and assists.
    Points: 5 for a goal, 3 for an assist.
    """
    df_player['Points'] = df_player['Gls'].astype(int) * 5 + df_player['Ast'].astype(int) * 3
    return df_player[['Season', 'Date', 'Comp', 'Round', 'Opponent', 'Result', 'Pos', 'Min', 'Gls', 'Ast', 'Points']]

def attacker_points(df_player):
    """
    Calculate points for an attacker based on goals, assists, and clean sheets.
    Points: 5 for a goal, 3 for an assist, 1 for a clean sheet.
    """
    df_player['CleanSheets'] = df_player['GoalsConceded'].astype(int).apply(lambda x: 1 if x == 0 else 0)
    df_player['GoalDifference'] = df_player['GoalsScored'].astype(int) - df_player['GoalsConceded'].astype(int)
    df_player['Points'] = (df_player['Gls'].astype(int) * 5 +
                           df_player['Ast'].astype(int) * 3 +
                           df_player['CleanSheets'].astype(int))
    return df_player[['Season', 'Date', 'Comp', 'Round', 'Opponent', 'Result', 'Pos', 'Min', 'Gls', 'Ast', 'Points']]


def defender_points(df_player):
    """
    Calculate points for a defender based on goals, assists, and clean sheets.
    Points: 6 for a goal, 3 for an assist, 1 for a clean sheet.
    """
    df_player['Points'] = (df_player['Gls'].astype(int) * 6 +
                           df_player['Ast'].astype(int) * 3 +
                           df_player['CleanSheets'].astype(int))
    return df_player[['Season', 'Date', 'Comp', 'Round', 'Opponent', 'Result', 'Pos', 'Min', 'Gls', 'Ast', 'Points']]

def keeper_points(df_player):
    """
    Calculate points for a goalkeeper based on clean sheets and saves.
    Points: 4 for a clean sheet, 1 for every 3 saves.
    """
    df_player['Points'] = (df_player['CleanSheets'].astype(int) * 4 +
                           df_player['Saves'].astype(int) // 3)
    return df_player[['Season', 'Date', 'Comp', 'Round', 'Opponent', 'Result', 'Pos', 'Min', 'Gls', 'Ast', 'Points']]

# %%
df_player = attacker_points(df_player)

# %%
df_player = df_player.reset_index(drop=True)

# %%
def player_elo(df_player, k=20):
    initial_elo = 1500.0  # Starting Elo rating
    df_player = df_player.reset_index(drop=True) # Ensure DataFrame is indexed correctly
    df_player['Elo'] = 0.0  # Initialize Elo column
    df_player.at[0, 'Elo'] = initial_elo  # Only the first match starts at 1500
    for i in range(1, len(df_player)):
        Ra = df_player.loc[i-1, 'Elo']
        Pa = df_player.loc[i-1, 'Points']
        # Expected score based on Elo (normalized to points scale)
        E_a = round( k/(1 + 10**(initial_elo/Ra)), 2)
        # Update Elo
        if Pa >= E_a:
            df_player.at[i, 'Elo'] = round((Ra + k * (Pa - E_a)), 3)
        else:
            # Lose points: penalize by k * (E_a * Pa - Pa)
            df_player.at[i, 'Elo'] = round((Ra + k * (Pa - E_a)), 3)
        last_elo = df_player.at[i, 'Elo']
    return last_elo

df_player_elo = player_elo(df_player)
# Out:
# Match 1: Ra=1500.0, Pa=6, E_a=1.82
# Match 2: Ra=1583.6, Pa=10, E_a=2.03
# Match 3: Ra=1743.0, Pa=1, E_a=2.42
# Match 4: Ra=1714.6, Pa=13, E_a=2.35
# Match 5: Ra=1927.6, Pa=0, E_a=2.86
# Match 6: Ra=1870.4, Pa=11, E_a=2.73
# Match 7: Ra=2035.8, Pa=4, E_a=3.1
# Match 8: Ra=2053.8, Pa=5, E_a=3.14
# Match 9: Ra=2091.0, Pa=15, E_a=3.22
# Match 10: Ra=2326.6, Pa=16, E_a=3.69
# Match 169: Ra=2744.0, Pa=1, E_a=4.42
# Match 170: Ra=2675.6, Pa=9, E_a=4.31
# Match 171: Ra=2769.4, Pa=5, E_a=4.46

# %%
df_player_elo
# Out:
# np.float64(2780.2)

# %%
df_player_elo.to_csv("elo.csv", index=False)

# %%
import aiohttp
from fpl import FPL

async def get_player_cost(player_name):
    async with aiohttp.ClientSession() as session:
        fpl = FPL(session)
        players = await fpl.get_players()
        for player in players:
            full_name = f"{player.first_name} {player.second_name}"
            if full_name.lower() == player_name.lower():
                print(f"{full_name} costs £{player.now_cost / 10}m")
                return player.now_cost / 10
        print(f"Player '{player_name}' not found.")
        return None

# Example usage:
cost = await get_player_cost("Erling Haaland")
# Out:
# Erling Haaland costs £14.0m

# %%
import pandas as pd
from pulp import LpProblem, LpVariable, lpSum, LpMaximize, LpBinary, LpStatus, value

def select_top_n_squads(csv_path="elo_ratings.csv", budget=85, attacker_count=3, midfielder_count=4, defender_count=3, keeper_count=1, top_n=3):
    df = pd.read_csv(csv_path)
    gks = df[df['Position'] == 'Keeper'].nlargest(10, 'Elo')
    defs = df[df['Position'] == 'Defender'].nlargest(40, 'Elo')
    mids = df[df['Position'] == 'Midfielder'].nlargest(40, 'Elo')
    atts = df[df['Position'] == 'Attacker'].nlargest(40, 'Elo')
    squad_df = pd.concat([gks, defs, mids, atts], ignore_index=True)

    squads = []
    used_combinations = set()

    for _ in range(top_n):
        choices = [LpVariable(f"player_{i}", cat=LpBinary) for i in range(len(squad_df))]
        prob = LpProblem("FPL_Squad_Selection", LpMaximize)
        prob += lpSum([choices[i] * squad_df.loc[i, "Elo"] for i in range(len(squad_df))])
        prob += lpSum([choices[i] * squad_df.loc[i, "Cost"] for i in range(len(squad_df))]) <= budget
        prob += lpSum([choices[i] for i in range(len(squad_df)) if squad_df.loc[i, "Position"] == "Keeper"]) == keeper_count
        prob += lpSum([choices[i] for i in range(len(squad_df)) if squad_df.loc[i, "Position"] == "Defender"]) == defender_count
        prob += lpSum([choices[i] for i in range(len(squad_df)) if squad_df.loc[i, "Position"] == "Midfielder"]) == midfielder_count
        prob += lpSum([choices[i] for i in range(len(squad_df)) if squad_df.loc[i, "Position"] == "Attacker"]) == attacker_count

        # Exclude previous squads
        for prev in used_combinations:
            prob += lpSum([choices[i] for i in prev]) <= len(prev) - 1

        prob.solve()
        selected = [i for i in range(len(squad_df)) if choices[i].varValue == 1]
        if not selected or tuple(selected) in used_combinations:
            break
        used_combinations.add(tuple(selected))
        result = squad_df.iloc[selected]
        squads.append(result)

    for idx, squad in enumerate(squads, 1):
        print(f"\nSquad {idx}:")
        print(f"Total Cost: {squad['Cost'].sum()} million")
        print(f"Total Elo: {squad['Elo'].sum()}")
        print(squad)
    return squads

# Example usage:
select_top_n_squads("elo_ratings.csv", budget=85, top_n=3)
# Out:
# Squad 1:
# Total Cost: 84.5 million
# Total Elo: 46507.1
#                  Player    Position     Elo  Cost
# 0       Jordan_Pickford      Keeper  3217.0   5.5
# 10      Maxim_De_Cuyper    Defender  3313.1   4.5
#  51          Bukayo_Saka  Midfielder  4458.3  10.0
#  52        Florian_Wirtz  Midfielder  4108.1   8.5
#  54     Leandro_Trossard  Midfielder  3824.4   7.0
#  90       Erling_Haaland    Attacker  6377.1  14.0
#  91      Viktor_Gyökeres    Attacker  5828.4   9.0
#  92       Benjamin_Sesko    Attacker  4458.6   7.5,
#                   Player    Position     Elo  Cost
#  2     David_Raya_Martín      Keeper  3116.6   5.5
#  10      Maxim_De_Cuyper    Defender  3313.1   4.5
#  11   Daniel_Muñoz_Mejía    Defender  3281.3   5.5
#  12  Pedro_Porro_Sauceda    Defender  2940.5   5.5
#  50           Cody_Gakpo  Midfielder  4700.3   7.5
#  51          Bukayo_Saka  Midfielder  4458.3  10.0
#  52        Florian_Wirtz  Midfielder  4108.1   8.5
#  54     Leandro_Trossard  Midfielder  3824.4   7.0
#  90       Erling_Haaland    Attacker  6377.1  14.0
#  91      Viktor_Gyökeres    Attacker  5828.4   9.0
#  92       Benjamin_Sesko    Attacker  4458.6   7.5]

# %%
import pandas as pd
from pulp import LpProblem, LpVariable, lpSum, LpMaximize, LpBinary

def select_top_n_squads(csv_path="elo_ratings.csv", budget=85, attacker_count=3, midfielder_count=4, defender_count=3, keeper_count=1, top_n=3):
    df = pd.read_csv(csv_path)
    gks = df[df['Position'] == 'Keeper'].nlargest(10, 'Elo')
    defs = df[df['Position'] == 'Defender'].nlargest(40, 'Elo')
    mids = df[df['Position'] == 'Midfielder'].nlargest(40, 'Elo')
    atts = df[df['Position'] == 'Attacker'].nlargest(40, 'Elo')
    squad_df = pd.concat([gks, defs, mids, atts], ignore_index=True)

    squads = []
    used_players = set()

    for _ in range(top_n):
        # Only use players not already selected
        available_idx = [i for i in range(len(squad_df)) if squad_df.loc[i, "Player"] not in used_players]
        if len(available_idx) < (keeper_count + defender_count + midfielder_count + attacker_count):
            break

        choices = [LpVariable(f"player_{i}", cat=LpBinary) for i in available_idx]
        prob = LpProblem("FPL_Squad_Selection", LpMaximize)
        prob += lpSum([choices[j] * squad_df.loc[available_idx[j], "Elo"] for j in range(len(available_idx))])
        prob += lpSum([choices[j] * squad_df.loc[available_idx[j], "Cost"] for j in range(len(available_idx))]) <= budget
        prob += lpSum([choices[j] for j in range(len(available_idx)) if squad_df.loc[available_idx[j], "Position"] == "Keeper"]) == keeper_count
        prob += lpSum([choices[j] for j in range(len(available_idx)) if squad_df.loc[available_idx[j], "Position"] == "Defender"]) == defender_count
        prob += lpSum([choices[j] for j in range(len(available_idx)) if squad_df.loc[available_idx[j], "Position"] == "Midfielder"]) == midfielder_count
        prob += lpSum([choices[j] for j in range(len(available_idx)) if squad_df.loc[available_idx[j], "Position"] == "Attacker"]) == attacker_count

        prob.solve()
        selected = [available_idx[j] for j in range(len(available_idx)) if choices[j].varValue == 1]
        if not selected:
            break
        used_players.update(squad_df.loc[selected, "Player"])
        result = squad_df.iloc[selected]
        squads.append(result)

    for idx, squad in enumerate(squads, 1):
        print(f"\nSquad {idx}:")
        print(f"Total Cost: {squad['Cost'].sum()} million")
        print(f"Total Elo: {squad['Elo'].sum()}")
        print(squad)
    return squads

# Example usage:
select_top_n_squads("elo_ratings.csv", budget=85, top_n=4)
# Out:
# Squad 1:
# Total Cost: 84.5 million
# Total Elo: 46507.1
#                  Player    Position     Elo  Cost
# 0       Jordan_Pickford      Keeper  3217.0   5.5
# 10      Maxim_De_Cuyper    Defender  3313.1   4.5
# 11   Daniel_Muñoz_Mejía    Defender  3281.3   5.5
# 12  Pedro_Porro_Sauceda    Defender  2940.5   5.5
# 50           Cody_Gakpo  Midfielder  4700.3   7.5
# 51          Bukayo_Saka  Midfielder  4458.3  10.0
# 52        Florian_Wirtz  Midfielder  4108.1   8.5
# 54     Leandro_Trossard  Midfielder  3824.4   7.0
# 90       Erling_Haaland    Attacker  6377.1  14.0
# 91      Viktor_Gyökeres    Attacker  5828.4   9.0
# 92       Benjamin_Sesko    Attacker  4458.6   7.5
#
# Squad 2:
# Total Cost: 77.0 million
# Total Elo: 37445.1
#                 Player    Position     Elo  Cost
# 1          André_Onana      Keeper  3193.8   5.0
# 13     Virgil_van_Dijk    Defender  2747.5   6.0
# 14      Joško_Gvardiol    Defender  2657.2   6.0
# 15        Fabian_Schär    Defender  2470.9   5.5
# 53         Cole_Palmer  Midfielder  3831.7  10.5
# 55     Martin_Ødegaard  Midfielder  3592.6   8.0
# 56  Dominik_Szoboszlai  Midfielder  3541.1   6.5
# 57        Eberechi_Eze  Midfielder  3423.7   7.5
# 93       Omar_Marmoush    Attacker  4103.4   8.5
# 94          Joël_Piroe    Attacker  3951.5   5.5
# 95        Jarrod_Bowen    Attacker  3931.7   8.0
#
# Squad 3:
# Total Cost: 69.0 million
# Total Elo: 34954.600000000006
#                                      Player    Position     Elo  Cost
# 2                         David_Raya_Martín      Keeper  3116.6   5.5
# 16                           Ferdi_Kadıoğlu    Defender  2465.2   4.5
# 17                             Milos_Kerkez    Defender  2453.4   6.0
# 18                          Kieran_Trippier    Defender  2445.7   5.0
# 58  Bernardo_Mota_Veiga_de_Carvalho_e_Silva  Midfielder  3347.1   6.5
# 59                           James_Maddison  Midfielder  3215.1   7.0
# 60                           İlkay_Gündoğan  Midfielder  3207.3   6.5
# 61                      Alexis_Mac_Allister  Midfielder  3175.9   6.5
# 96                              Kai_Havertz    Attacker  3907.9   7.5
# 97                          Niclas_Füllkrug    Attacker  3852.4   6.0
# 98                             Bryan_Mbeumo    Attacker  3768.0   8.0
#
# Squad 4:
# Total Cost: 68.0 million
# Total Elo: 33911.5
#                        Player    Position     Elo  Cost
# 3              James_Trafford      Keeper  3051.5   5.0
# 19                Ian_Maatsen    Defender  2445.5   4.5
# 20           Andrew_Robertson    Defender  2441.1   6.0
# 21            Rayan_Aït-Nouri    Defender  2438.4   6.0
# 62               Matt_O'Riley  Midfielder  3157.2   5.5
# 63          Tijjani_Reijnders  Midfielder  3131.8   5.5
# 64                Declan_Rice  Midfielder  3090.7   6.5
# 65            Justin_Kluivert  Midfielder  3014.1   7.0
# 99        Luis_Díaz_Marulanda    Attacker  3739.2   8.0
# 100  Dominic_Solanke-Mitchell    Attacker  3703.0   7.5
# 101            Mohammed_Kudus    Attacker  3699.0   6.5
# [                 Player    Position     Elo  Cost
#  0       Jordan_Pickford      Keeper  3217.0   5.5
#  10      Maxim_De_Cuyper    Defender  3313.1   4.5
#  11   Daniel_Muñoz_Mejía    Defender  3281.3   5.5
#  12  Pedro_Porro_Sauceda    Defender  2940.5   5.5
#  50           Cody_Gakpo  Midfielder  4700.3   7.5
#  51          Bukayo_Saka  Midfielder  4458.3  10.0
#  52        Florian_Wirtz  Midfielder  4108.1   8.5
#  54     Leandro_Trossard  Midfielder  3824.4   7.0
#  90       Erling_Haaland    Attacker  6377.1  14.0
#  91      Viktor_Gyökeres    Attacker  5828.4   9.0
#  92       Benjamin_Sesko    Attacker  4458.6   7.5,
#                  Player    Position     Elo  Cost
#  1          André_Onana      Keeper  3193.8   5.0
#  13     Virgil_van_Dijk    Defender  2747.5   6.0
#  14      Joško_Gvardiol    Defender  2657.2   6.0
#  15        Fabian_Schär    Defender  2470.9   5.5
#  53         Cole_Palmer  Midfielder  3831.7  10.5
#  55     Martin_Ødegaard  Midfielder  3592.6   8.0
#  56  Dominik_Szoboszlai  Midfielder  3541.1   6.5
#  57        Eberechi_Eze  Midfielder  3423.7   7.5
#  93       Omar_Marmoush    Attacker  4103.4   8.5
#  94          Joël_Piroe    Attacker  3951.5   5.5
#  95        Jarrod_Bowen    Attacker  3931.7   8.0,
#                                       Player    Position     Elo  Cost
#  2                         David_Raya_Martín      Keeper  3116.6   5.5
#  16                           Ferdi_Kadıoğlu    Defender  2465.2   4.5
#  17                             Milos_Kerkez    Defender  2453.4   6.0
#  18                          Kieran_Trippier    Defender  2445.7   5.0
#  58  Bernardo_Mota_Veiga_de_Carvalho_e_Silva  Midfielder  3347.1   6.5
#  59                           James_Maddison  Midfielder  3215.1   7.0
#  60                           İlkay_Gündoğan  Midfielder  3207.3   6.5
#  61                      Alexis_Mac_Allister  Midfielder  3175.9   6.5
#  96                              Kai_Havertz    Attacker  3907.9   7.5
#  97                          Niclas_Füllkrug    Attacker  3852.4   6.0
#  98                             Bryan_Mbeumo    Attacker  3768.0   8.0,
#                         Player    Position     Elo  Cost
#  3              James_Trafford      Keeper  3051.5   5.0
#  19                Ian_Maatsen    Defender  2445.5   4.5
#  20           Andrew_Robertson    Defender  2441.1   6.0
#  21            Rayan_Aït-Nouri    Defender  2438.4   6.0
#  62               Matt_O'Riley  Midfielder  3157.2   5.5
#  63          Tijjani_Reijnders  Midfielder  3131.8   5.5
#  64                Declan_Rice  Midfielder  3090.7   6.5
#  65            Justin_Kluivert  Midfielder  3014.1   7.0
#  99        Luis_Díaz_Marulanda    Attacker  3739.2   8.0
#  100  Dominic_Solanke-Mitchell    Attacker  3703.0   7.5
#  101            Mohammed_Kudus    Attacker  3699.0   6.5]

# %%
select_top_n_squads("elo_ratings.csv", budget=100, top_n=3, attacker_count=4, midfielder_count=6, defender_count=4, keeper_count=2)
from datetime import datetime
async def get_current_gw_player_details():
    async with aiohttp.ClientSession() as session:
        fpl = FPL(session)
        gameweeks = await fpl.get_gameweeks()
        current_gw = next(gw for gw in gameweeks if gw.is_current)
        gw_id = current_gw.id

        players = await fpl.get_players()
        rows = []
        for player in players:
            history = await fpl.get_player_summary(player.id)
            gw_entry = None
            for g in history.history:
                if 'event' in g and g['event'] == gw_id:
                    gw_entry = g
                    break
                elif 'round' in g and g['round'] == gw_id:
                    gw_entry = g
                    break
            if gw_entry:
                rows.append({
                    "Player": f"{player.first_name} {player.second_name}",
                    "Date": gw_entry.get('kickoff_time', None),
                    "Comp": "Premier League",
                    "Round": gw_entry.get('event', gw_entry.get('round', None)),
                    "Opponent": gw_entry.get('opponent_team', None),
                    "Result": gw_entry.get('result', None),
                    "Min": gw_entry.get('minutes', None),
                    "Gls": gw_entry.get('goals_scored', None),
                    "Ast": gw_entry.get('assists', None),
                    'was_home': gw_entry.get('was_home', None),
                    'team_a_score': gw_entry.get('team_a_score', None),
                    'team_h_score': gw_entry.get('team_h_score', None)
                })
        df = pd.DataFrame(rows)
        # Convert 'Date' column from ISO format with time to just date (YYYY-MM-DD)
        df['Date'] = df['Date'].apply(lambda x: datetime.fromisoformat(x.replace("Z", "")).date() if isinstance(x, str) else x)
        return df

# Example usage:
df = await get_current_gw_player_details()
df.to_csv("current_gw_player_details.csv", index=False)
print(df.head())
# Out:
#                          Player        Date            Comp  Round  Opponent  \
# 0             David Raya Martín  2025-08-17  Premier League      1        14
# 1    Kepa Arrizabalaga Revuelta  2025-08-17  Premier League      1        14
# 2                     Karl Hein  2025-08-17  Premier League      1        14
# 3                 Tommy Setford  2025-08-17  Premier League      1        14
# 4  Gabriel dos Santos Magalhães  2025-08-17  Premier League      1        14
#
#   Result  Min  Gls  Ast  was_home  team_a_score  team_h_score
# 0   None   90    0    0     False             1             0
# 1   None    0    0    0     False             1             0
# 2   None    0    0    0     False             1             0
# 3   None    0    0    0     False             1             0
# 4   None   90    0    0     False             1             0

# %%
df['was_home'].head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: was_home, dtype: bool

# %%
df['Season'] = '2025-2026'
df['Comp'] = 'Premier League'
df['Result'] = df.apply(lambda x: f"{x['team_h_score']}-{x['team_a_score']}" if x['was_home'] else f"{x['team_a_score']}-{x['team_h_score']}", axis=1)
df['Pos'] = None

# %%
df['Elo'] = 0

# %%
for _, row in df.iterrows():
    player_name = row['Player']
    player_file = f"./elo_data/{player_name.replace(' ', '_')}.csv"
    
    new_player_data = df[df['Player'] == player_name].copy()
    # Only select columns that exist in df
    columns_to_select = [col for col in ['Season', 'Date','Comp', 'Round', 'Opponent', 'Result', 'Pos', 'Min', 'Gls', 'Ast', 'Points', 'Elo'] if col in df.columns]
    new_player_data = new_player_data[columns_to_select]
    
    if os.path.exists(player_file):
        player_df = pd.read_csv(player_file)
        # Process player_df as needed
        # print(f"Processing {player_name} from {player_file}")
        player_df2 = pd.concat([player_df, new_player_data], ignore_index=True)
        player_df2.drop_duplicates(subset = ['Season', 'Date','Comp', 'Round', 'Opponent', 'Result', 'Pos', 'Min', 'Gls', 'Ast', 'Points', 'Elo'], keep='last', inplace=True)
        print(player_df2.head())
        # Overwrite the old file with the updated DataFrame
        player_df2.to_csv(player_file, index=False)
    else:
        print(f"File for {player_name} does not exist.")
# Out:
#       Season        Date            Comp        Round        Opponent Result  \
# 0  2022-2023  2022-08-07  Premier League  Matchweek 1  Leicester City  D 2–2
# 1  2022-2023  2022-08-13  Premier League  Matchweek 2  Manchester Utd  W 4–0
# 2  2022-2023  2022-08-20  Premier League  Matchweek 3          Fulham  L 2–3
# 3  2022-2023  2022-08-27  Premier League  Matchweek 4         Everton  D 1–1
# 4  2022-2023  2022-08-30  Premier League  Matchweek 5  Crystal Palace  D 1–1
#
#   Pos  Min  Gls  Ast  Points     Elo
# 0  GK   90    0    0     1.0  1200.0
# 1  GK   90    0    0     5.0  1198.8
# 2  GK   90    0    0     2.0  1277.6
# 3  GK   90    0    0     2.0  1292.4
# 4  GK   90    0    0     1.0  1306.6
#       Season        Date            Comp         Round          Opponent  \
# 0  2022-2023  2022-09-06    Champions Lg   Group stage  hr Dinamo Zagreb
# 1  2022-2023  2022-09-14    Champions Lg   Group stage    at RB Salzburg
# 2  2022-2023  2022-10-01  Premier League   Matchweek 9    Crystal Palace
# 3  2022-2023  2022-10-05    Champions Lg   Group stage          it Milan
# 4  2022-2023  2022-10-08  Premier League  Matchweek 10            Wolves
#
#   Result Pos  Min  Gls  Ast  Points     Elo
# 0  L 0–1  GK   90    0    0     0.0  1200.0
# 1  D 1–1  GK   90    0    0     0.0  1182.2
# 2  W 2–1  GK   90    0    0     0.0  1165.2
# 3  W 3–0  GK   90    0    0     4.0  1145.6
# 4  W 3–0  GK   90    0    0     4.0  1210.2
# File for Karl Hein does not exist.
#       Season        Date     Comp           Round           Opponent Result  \
# 0  2024-2025  2024-10-30  EFL Cup    Fourth round            Preston  W 3–0
# 1  2024-2025  2024-12-01      PL2  Regular season           Brighton  D 1–1
# 2  2024-2025  2025-01-24      PL2  Regular season  Nottingham Forest  W 2–0
# 3  2024-2025  2025-02-21      PL2  Regular season   Newcastle United  W 4–1
# 4  2024-2025  2025-03-31      PL2  Regular season       Norwich City  W 3–0
#
#   Pos   Min  Gls  Ast  Points     Elo
# 0  GK  90.0    0    0     4.0  1200.0
# 1  GK  90.0    0    0     0.0  1219.6
# 2  GK  90.0    0    0     4.0  1157.8
# 3  GK  90.0    0    0     0.0  1180.6
# 4  GK  90.0    0    0     4.0  1121.6
#       Season        Date            Comp        Round        Opponent Result  \
# 0  2022-2023  2022-08-05  Premier League  Matchweek 1  Crystal Palace  W 2–0
# 1  2022-2023  2022-08-13  Premier League  Matchweek 2  Leicester City  W 4–2
# 2  2022-2023  2022-08-20  Premier League  Matchweek 3     Bournemouth  W 3–0
# 3  2022-2023  2022-08-27  Premier League  Matchweek 4          Fulham  W 2–1
# 4  2022-2023  2022-08-31  Premier League  Matchweek 5     Aston Villa  W 2–1
#
#   Pos  Min  Gls  Ast  Points     Elo
# 0
#                  Opponent Result    Pos  Min  Gls  Ast  Points     Elo
# 0                Oostende  W 2–0     FW   10    1    0     5.0  1200.0
# 1           Cercle Brugge  L 0–1  CM,FW   45    0    0     0.0  1239.6
# 2  ee Paide Linnameeskond  W 2–0     FW   79    1    0     5.0  1176.4
# 3                 Seraing  W 3–1     FW   85    1    0     5.0  1217.8
# 4  ee Paide Linnameeskond  W 3–0      0   33    1    1     8.0  1256.2
#       Season        Date                 Comp        Round       Opponent  \
# 0  2022-2023  2022-06-06  UEFA Nations League     League A     dk Denmark
# 1  2022-2023  2022-06-13  UEFA Nations League     League A     dk Denmark
# 2  2022-2023  2022-08-07           Bundesliga  Matchweek 1     RB Leipzig
# 3  2022-2023  2022-08-13           Bundesliga  Matchweek 2  Werder Bremen
# 4  2022-2023  2022-08-20           Bundesliga  Matchweek 3       Freiburg
#
#   Result Pos  Min  Gls  Ast  Points     Elo
# 0  L 1–2  FW   45    0    0     0.0  1200.0
# 1  L 0–2  FW   64    0    0     0.0  1139.6
# 2  D 1–1  FW   63    0    1     3.0  1083.8
# 3  D 2–2  FW   80    0    2     6.0  1120.0
# 4  L 0–1  FW   90    0    0     0.0  1214.2
# File for Leon Chiwome does not exist.
# File for Nathan Fraser does not exist.
# File for Jhon Arias does not exist.
#       Season        Date         Comp         Round    Opponent Result Pos  \
# 0  2022-2023  2023-04-10  Eliteserien   Matchweek 1   Haugesund  W 3–0  LB
# 1  2022-2023  2023-04-16  Eliteserien   Matchweek 2         Odd  L 0–2  LB
# 2  2022-2023  2023-04-22  Eliteserien   Matchweek 3   Vålerenga  W 3–1  LB
# 3  2022-2023  2023-04-29  Eliteserien   Matchweek 4  Bodø/Glimt  D 2–2  LB
# 4  2022-2023  2023-05-03  Eliteserien  Matchweek 18   Rosenborg  W 2–0  LB
#
#    Min  Gls  Ast  Points     Elo
# 0   80    0    1     7.0  1200.0
# 1   90    0    0     0.0  1279.6
# 2   90    0    0     0.0  1213.4
# 3   79    0    0     0.0  1152.0
# 4   90    0    0     4.0  1095.2

# %%
import os
players = []
for file in os.listdir('./elo_data'):
    if file.endswith('.csv'):
        player_name = file[:-4]
        players.append(player_name)
        with open(os.path.join('./elo_data', file), 'r') as f:
            da
elo_data = []
# Out:
# Aaron_Ramsdale
# Aaron_Wan-Bissaka
# Aarón_Anselmino
# Abdallah_Sima
# Abdukodir_Khusanov
# Adama_Traoré_Diarra
# Adam_Aznou
# Adam_Smith
# Adam_Webster
# Adam_Wharton
# Adrian_Mazilu
# Adrien_Truffert
# Ahmed_Abdullahi
# Aji_Alese
# Alan_Browne
# Albert_Sambi_Lokonga
# Alejandro_Garnacho_Ferreyra
# Alexander_Isak
# Alexis_Mac_Allister
# Alex_Cairns
# Alex_Iwobi
# Alex_Paulsen
# Alex_Scott
# Alfie_Pond
# Alisson_Becker
# Alphonse_Areola
# Altay_Bayındır
# Amadou_Onana
# Amad_Diallo
# Amara_Nallo
# Andreas_Hoelgebaum_Pereira
# Andrew_Moran
# Andrew_Robertson
# Andrey_Nascimento_dos_Santos
# Sven_Botman
# Sverre_Nypan
# Sávio_Moreira_de_Oliveira
# Séamus_Coleman
# Sékou_Koné
# Taiwo_Awoniyi
# Takai_Kōta
# Tanaka_Ao
# Tariq_Lamptey
# Tawanda_Chirewa
# Tijjani_Reijnders
# Timothy_Castagne
# Timothée_Pembélé
# Tim_Iroegbunam
# Tino_Livramento
# Toby_Collyer
# Tommy_Setford
# Tom_Cairney
# Tom_Edozie
# Tom_Heaton
# Tom_McGill
# Tomáš_Souček
# Tosin_Adarabioyo
# Toti_Gomes
# Trai_Hume
# Trevoh_Chalobah
# Trey_Nyoni
# Tyler_Adams
# Tyler_Fredricson
# Tyler_Morton
# Tyrell_Malacia
# Tyrick_Mitchell
# Tyrique_George
# Tyrone_Mings
# Viktor_Gyökeres
# Virgil_van_Dijk
# Vitalii_Mykolenko
# Vitaly_Janelt
# Vitor_de_Oliveira_Nunes_dos_Reis
# Václav_Hladký
# Walter_Benítez
# Wesley_Fofana
# Wilfried_Gnonto
# William_Osula
# William_Saliba
# Willy_Boly
# Will_Lankshear
# Wilson_Isidor
# Wilson_Odobert
# Yankuba_Minteh
# Yasin_Ayari
# Yasin_Özcan
# Yehor_Yarmoliuk
# Yerson_Mosquera_Valdelamar
# Yoane_Wissa
# Youri_Tielemans
# Youssef_Ramalho_Chermiti
# Yunus_Emre_Konak
# Yves_Bissouma
# Zach_Abbott
# Zach_Marsh
# Zain_Silcott-Duberry
# Zeki_Amdouni
# Zian_Flemming
# Zépiqueno_Redmond
# Álex_Moreno_Lopera
# Ármin_Pécsi
# Đorđe_Petrović
# İlkay_Gündoğan

# %%
dfi = pd.read_csv("initial_elo.csv")
dfw = pd.read_csv("current_gw_player_details.csv")
dfw['Player'] = dfw['Player'].apply(lambda x: x.replace(" ", "_"))

# %%
dfi.head()
# Out:
#             Player    Position     Elo  Cost
# 0  Viktor_Gyökeres    Attacker  2891.2   9.0
# 1    Mohamed_Salah  Midfielder  2456.6  14.5
# 2   Erling_Haaland    Attacker  1500.0  14.0
# 3   Alexander_Isak    Attacker  1500.0  10.5
# 4     Eberechi_Eze  Midfielder  1947.6   7.5

# %%
dfw.head()
# Out:
#                          Player                  Date            Comp  Round  \
# 0             David_Raya_Martín  2025-08-17T15:30:00Z  Premier League      1
# 1    Kepa_Arrizabalaga_Revuelta  2025-08-17T15:30:00Z  Premier League      1
# 2                     Karl_Hein  2025-08-17T15:30:00Z  Premier League      1
# 3                 Tommy_Setford  2025-08-17T15:30:00Z  Premier League      1
# 4  Gabriel_dos_Santos_Magalhães  2025-08-17T15:30:00Z  Premier League      1
#
#    Opponent  Result  Min  Gls  Ast
# 0        14     NaN   90    0    0
# 1        14     NaN    0    0    0
# 2        14     NaN    0    0    0
# 3        14     NaN    0    0    0
# 4        14     NaN   90    0    0

# %%
"David Raya Martín".replace(" ", "_")
# Out:
# 'David_Raya_Martín'

# %%
df_work = dfw.merge(dfi, on='Player', how='left')
df_work = df_work[df_work['Position'].isna()]

# %%
df_work.to_csv("df_work.csv", index=False)
